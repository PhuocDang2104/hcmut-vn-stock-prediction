# %% [markdown]
# # 21 Final Decision Support
#
# Sections:
# 1. Load combined predictions
# 2. Build consensus summary
# 3. Inspect disagreement cases
# 4. Summarize final recommendation
# 5. Export report-ready artifacts

# %%
import pandas as pd

from vnstock.visualization.dashboards import consensus_summary

all_predictions = pd.read_parquet('outputs/predictions/all_predictions.parquet')
consensus = consensus_summary(all_predictions)
consensus.head()
