# %% [markdown]
# # 20 Compare Models
#
# Sections:
# 1. Load all predictions
# 2. Normalize schema
# 3. Compute leaderboard
# 4. Compare by symbol and date
# 5. Plot ranking and residual views
# 6. Export aggregated artifacts

# %%
from vnstock.evaluation.compare import load_all_predictions
from vnstock.evaluation.leaderboard import build_leaderboard

predictions = load_all_predictions('outputs/predictions')
leaderboard = build_leaderboard('outputs/predictions')
predictions.head(), leaderboard
