# %% [markdown]
# # 00 Project Setup
#
# Muc tieu:
# - Kiem tra workspace va Python path.
# - Nap config goc cua du an.
# - Xac nhan thu muc data, outputs, registry.

# %%
from pathlib import Path

from vnstock.utils.io import read_yaml
from vnstock.utils.paths import project_paths, repo_root

root = repo_root()
project = read_yaml(root / 'configs' / 'project.yaml')
paths = project_paths()
root, project, paths
