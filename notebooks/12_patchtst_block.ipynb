# %% [markdown]
# # 12 PatchTST Block
#
# Sections:
# 1. Setup
# 2. Load config
# 3. Load `data/processed/patchtst/`
# 4. Validate patching metadata
# 5. Train PatchTST
# 6. Infer on test
# 7. Evaluate and visualize
# 8. Export predictions and metrics

# %%
from vnstock.models.patchtst.dataset import load_split
from vnstock.models.patchtst.model import build_model_spec
from vnstock.utils.io import read_yaml

config = read_yaml('configs/models/patchtst.yaml')
train_frame = load_split('data/processed/patchtst', 'train')
model_spec = build_model_spec(config)
train_frame.head(), model_spec
