# %% [markdown]
# # 11 iTransformer Block
#
# Sections:
# 1. Setup
# 2. Load config
# 3. Load `data/processed/itransformer/`
# 4. Inspect panel schema
# 5. Train iTransformer
# 6. Infer on test
# 7. Evaluate and visualize
# 8. Export predictions and metrics

# %%
from vnstock.models.itransformer.dataset import load_split
from vnstock.models.itransformer.model import build_model_spec
from vnstock.utils.io import read_yaml

config = read_yaml('configs/models/itransformer.yaml')
train_frame = load_split('data/processed/itransformer', 'train')
model_spec = build_model_spec(config)
train_frame.head(), model_spec
