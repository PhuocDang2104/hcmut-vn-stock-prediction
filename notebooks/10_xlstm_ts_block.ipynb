# %% [markdown]
# # 10 xLSTM-TS Block
#
# Sections:
# 1. Setup
# 2. Load config
# 3. Load `data/processed/xlstm_ts/`
# 4. Validate tensor shapes
# 5. Train xLSTM-TS
# 6. Infer on test
# 7. Evaluate and visualize
# 8. Export predictions and metrics

# %%
from vnstock.models.xlstm_ts.dataset import load_array_dataset
from vnstock.models.xlstm_ts.model import build_model_spec
from vnstock.utils.io import read_yaml

config = read_yaml('configs/models/xlstm_ts.yaml')
dataset = load_array_dataset('data/processed/xlstm_ts')
model_spec = build_model_spec(config)
dataset, model_spec
