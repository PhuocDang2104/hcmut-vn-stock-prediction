# %% [markdown]
# # 13 Kronos Block
#
# Sections:
# 1. Setup
# 2. Load config
# 3. Load `data/processed/kronos/`
# 4. Validate adapter export
# 5. Run Kronos integration
# 6. Infer on test
# 7. Evaluate and visualize
# 8. Export predictions and metrics

# %%
from vnstock.models.kronos.dataset import load_split
from vnstock.utils.io import read_yaml

config = read_yaml('configs/models/kronos.yaml')
train_frame = load_split('data/processed/kronos', 'train')
config, train_frame.head()
